# %%
import shutil, random, os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# This is small data set path for testing purpose
# dirpath="/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/"
#dirpath="/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/"
# dirpath="/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/"
#dirpath='/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_1/'
#dirpath='/home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/'
# dirpath='/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_1/S1/Event_1/'
despath="/home/sultan/EEG/Source_Level_Analysis/csv_write_test/"

# %% [markdown]
# # Function for averaging the trial

# %%
def doAvgSave(chunk,fname):
    df1 = pd.read_csv(chunk[0])
    tmp = df1.copy()
    tmp = tmp.drop(columns=['cc1'] )
    #print tmp
    for c in range(1,len(chunk)):
        tmp1 = pd.read_csv(chunk[c])
        tmp1 = tmp1.drop(columns=['cc1'] )
        tmp = tmp + tmp1 # add those
        #print chunk[i]
    tmpd = tmp.div(len(chunk)) # average
#     plt.plot(tmp.iloc[8,1:].values)
#     plt.grid(True)
#     plt.show()
    df1.update(tmpd) # this is the new data frame with average 
    # write to some location 
    #df1.to_csv(fname+'.csv')
    df1.to_csv(fname+'.csv')
    t=np.linspace(-10,200,106)
    plt.plot(t,df1.iloc[1:3,1:].values.T*1e9)
    plt.xlim(-10, 210)
    plt.grid(True)
    plt.show()

# %%
# from os import walk
# from os.path import isfile, join
# f = []
# for (dirpath, dirnames, filenames) in walk(dirpath):
#     f.extend(join(dirpath, x) for x in filenames if x.endswith(".csv"))
#     break

# %%
# len(f)

# %% [markdown]
# # Read the csv file and feed to the function

# %%
# #dirpath="/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/"
# #dirpath="/home/sultan/EEG/Source_Level_Analysis/Extracted_CSV/"
# # dirpath="/home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S1/Event_3"
# dirpath='/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_1/'
# from os import walk
# from os.path import isfile, join
# f = []
# for (dirpath, dirnames, filenames) in walk(dirpath):
#     f.extend(join(dirpath, x) for x in filenames if x.endswith(".csv"))
#     break
# sample=50;
# totalchunk = len(f) / sample 
# print (totalchunk)
# # test purpose 
# # totalchunk = 2
# import numpy as np
# for i in range(totalchunk): # we will generate two at a time
#     mychunk = np.random.choice(f,size=sample,replace=False)
#     #print mychunk
#     # make sure the chunk element does not exist in the original list 
#     f = list(set(f) - set(mychunk))
#     #print f
#     fname='S11E'+str(i)
#     doAvgSave(mychunk,fname)

# %%
# len(f)

# %%
# sample=10;
# totalchunk = len(f) / sample 
# print (totalchunk)
# # test purpose 
# # totalchunk = 2
# import numpy as np
# for i in range(totalchunk): # we will generate two at a time
#     mychunk = np.random.choice(f,size=sample,replace=False)
#     #print mychunk
#     # make sure the chunk element does not exist in the original list 
#     f = list(set(f) - set(mychunk))
#     #print f
#     doAvgSave(mychunk)

# %%
# for i in range(10):
#     b=despath+'ff'+str(i)
#     print b

# %%
# dirpath="/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/"
# #dirpath="/home/sultan/EEG/Source_Level_Analysis/Extracted_CSV/"
# #dirpath="/home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S1/Event_3"
# from os import walk
# from os.path import isfile, join
# ff = []
# for (dirpath, dirnames, filenames) in walk(dirpath):
#     ff.extend(join(dirpath, x) for x in filenames if x.endswith(".csv"))
#     break

# %%
# len(ff)

# %%
# df1 = pd.read_csv(ff[0])
# tmp2 = df1.copy()
# tmp2 = tmp2.drop(columns=['cc1'] )
# tmp=0
# for i in range(0,len(ff)):
#         tmp1 = pd.read_csv(ff[i])
#         tmp1 = tmp1.drop(columns=['cc1'] )
#         tmp=tmp1+tmp
#          # add those
# #         print ff[i]
#         tmpd=tmp.div(len(ff))
# df1.update(tmpd)
# df1.to_csv(despath+'Ss2E'+str(i)+'.csv')
# t=np.linspace(-10,200,106)
# plt.plot(t,tmp.iloc[1:3,:].values.T*1e9)
# plt.xlim(-10, 210)
# plt.grid(True)
# plt.show()

# %%
# fname='S1e'+str(1)
# fname
# despath+fname

# %%
# for i in range(1,3):
#     for j in range(1,5):
#         b=dirpath+'S'+str(i)+'/'+'Event_'+str(j)+'/'
#         dpin=b
#         print dpin

# %%
# from os import walk
# from os.path import isfile, join
# f = []
# for (dirpath1, dirnames, filenames) in walk(dirpath1):
#     f.extend(join(dirpath1, x) for x in filenames if x.endswith(".csv"))
#     break
# sample=10;
# totalchunk = len(f) / sample 
# print (totalchunk)
# # test purpose 
# # totalchunk = 2
# import numpy as np
# for i in range(totalchunk): # we will generate two at a time
#     mychunk = np.random.choice(f,size=sample,replace=False)
#     #print mychunk
#     # make sure the chunk element does not exist in the original list 
#     f = list(set(f) - set(mychunk))
#     #print f
# #     fname='S'+str(i)+'/'+'Event_'+str()
#     doAvgSave(mychunk,fname)

# %%
# dirpath1=dpin

# %%
dirpath="/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/"

# %%
sub=3;# subject+1
Ev=5;#event+1
for k in range(1,sub):
    for j in range(1,Ev):
        b=dirpath+'S'+str(k)+'/'+'Event_'+str(j)+'/'
        dpin=b
        print dpin
        from os import walk
        from os.path import isfile, join
        f = []
        for (dpin, dirnames, filenames) in walk(dpin):
            f.extend(join(dpin, x) for x in filenames if x.endswith(".csv"))
            break
        #print f
        sample=10;
        totalchunk = len(f) / sample 
        print (totalchunk)
        # test purpose 
        # totalchunk = 2
        descr=despath+'S'+str(k)+'/'+'Event_'+str(j)
        os.makedirs(descr)
        import numpy as np
        for i in range(totalchunk): # we will generate two at a time
            mychunk = np.random.choice(f,size=sample,replace=False)
            #print mychunk
            # make sure the chunk element does not exist in the original list 
            f = list(set(f) - set(mychunk))
            #print f
            #fname=descr+'Av'+str(i)
            #fname='S'+str(k)+'event'+str(j)+'av'+str(i)
            fname=despath+'S'+str(k)+'/'+'Event_'+str(j)+'/'+'S'+str(k)+'event'+str(j)+'av'+str(i)
            doAvgSave(mychunk,fname)
# Out:
# /home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_1/
# 5
# /home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_2/
# 5
# /home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_3/
# 5
# /home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_4/
# 5
# /home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S2/Event_1/
# 5
# /home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S2/Event_2/
# 5
# /home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S2/Event_3/
# 5
# /home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S2/Event_4/
# 5

# %%
# from os import walk
# from os.path import isfile, join
# f = []
# for (dpin, dirnames, filenames) in walk(dpin):
#     f.extend(join(dpin, x) for x in filenames if x.endswith(".csv"))
#     break
# print f

# %%
# os.makedirs(despath+'/'+'S'+str(k)+'/'+'event'+str(j))

# %%
fname+'/'+'.csv'
# Out:
# '/home/sultan/EEG/Source_Level_Analysis/csv_write_test/S2/Event_4/S2event4av4/.csv'

# %%
descr=despath+'S'+str(k)+'/'+'Event_'+str(j)+'/'+'S'+str(k)+'event'+str(j)+'av'+str(i)
descr
# Out:
# '/home/sultan/EEG/Source_Level_Analysis/csv_write_test/S2/Event_4/S2event4av4'

# %%
fname+'.csv'
# Out:
# '/home/sultan/EEG/Source_Level_Analysis/csv_write_test/S2/Event_4/S2event4av4.csv'

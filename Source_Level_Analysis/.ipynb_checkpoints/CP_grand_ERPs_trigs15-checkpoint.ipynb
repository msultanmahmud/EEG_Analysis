# %%
import shutil, random, os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle

# %%
# Data path
# dirpath='/home/sultan/EEG/Source_Level_Analysis/10msWindow/'
#dirpath='/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/'
dirpath='/home/sultan/EEG/CP/CP_Source_data/'
# dirpath='/home/sultan/EEG/Source_Level_Analysis/Source_ERP/CP_sm_test/'
# dirpath="/home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S1/Event_3"

# %%
a=0;count=0;
#sub=[4, 5, 6, 7, 11, 12, 13, 15, 17, 18, 19, 20, 21, 25, 26, 27, 29, 30, 32]; HI=1;
# sub=[1, 2 ,3 ,8, 9, 10, 14 ,16, 22 ,23, 24 ,28 ,31]# NH=0;Subject ID number and class labels; 
sub=[1,2]
Ev=[1,5];#event number
for k in range(0,len(sub)):
    for j in range(0,len(Ev)):
        pnh=dirpath+'S'+str(sub[k])+'/'+'Trig_'+str(Ev[j])+'/'
        dpin=pnh
        print dpin
        from os import walk
        from os.path import isfile, join
        f = []
        for (dpin, dirnames, filenames) in walk(dpin):
            f.extend(join(dpin, x) for x in filenames if x.endswith(".csv"))
            break
        for i in range(0,len(f)):
            dd=pd.read_csv(f[i])
            dd1=dd.drop(dd.columns[0],axis=1)
            a=a+dd1
            count=count+1
dnhc=pd.DataFrame(a)
#         d2.insert(0,'label',np.zeros(len(d2)), True)
        # df.insert(2, "Age", [21, 23, 24, 21], True)
# d2
count
# Out:
# /home/sultan/EEG/CP/CP_Source_data/S1/Trig_1/
# /home/sultan/EEG/CP/CP_Source_data/S1/Trig_5/
# /home/sultan/EEG/CP/CP_Source_data/S2/Trig_1/
# /home/sultan/EEG/CP/CP_Source_data/S2/Trig_5/
# 600

# %%
# dnhc

# %% [markdown]
# # Writing a pickle file

# %%
# f = open('hierp.pckl', 'wb')
# pickle.dump(dhic,f)
# f.close()

# %%
# f = open('hierp.pckl', 'rb')
# obj = pickle.load(f)
# f.close()

# %% [markdown]
# # For a single ROI visualization

# %%
# # df1.to_csv(fname+'.csv')
# t=np.linspace(-200,800,500)
# plt.plot(t,dnhc.iloc[0,:].values.T*1e9/count)
# plt.xlim(-200, 800)
# plt.grid(True)
# plt.legend(['lBKS'])
# plt.show()

# %%
# dkr=pd.read_csv(dkpath)
rois=[66,67]
leg=['lPT','lPRC','rTRANS']

# %%
# datnhc =pd.read_csv(erppath+nhc)
# dnhc=datnhc.iloc[:,1:]
t=np.linspace(-200,800,500)
# plt.plot(t,dnhc.iloc[[36,37,40,41,48,49,66,67],:].values.T*1e9/count)
# plt.plot(t,dnhc.iloc[[36,40,48,66,67],:].values.T*1e9)
plt.plot(t,dnhc.iloc[rois,:].values.T*1e9)
plt.xlim(-200, 800)
plt.grid(True)
plt.xlabel("Time (ms)")
plt.ylabel("Voltage(nV)")
plt.title("ERPs of combined trig 1 & 5")
# plt.legend('1','2')
plt.legend(leg)
plt.show()

# %%
# # df1.to_csv(fname+'.csv')
# t=np.linspace(-200,800,500)
# # plt.plot(t,dnhc.iloc[[36,37,40,41,48,49,66,67],:].values.T*1e9/count)
# plt.plot(t,dnhc.iloc[[36,40,48,66,67],:].values.T/count)
# plt.xlim(-200, 800)
# plt.grid(True)
# plt.xlabel("Time (ms)")
# plt.ylabel("Voltage(nV)")
# plt.title("Combined 1 and 5 Trigers")
# plt.legend('1','2')
# plt.show()

# %% [markdown]
# # Write csv

# %%
# dnhc=dnhc/count
# despathw="/home/sultan/EEG/Source_Level_Analysis/Grand_ERPs/"
# dnhc.to_csv(despathw+'NH_clear_grand_erp.csv')

# %%
# a=0;count=0;
# # sub=[4, 5, 6, 7, 11, 12, 13, 15, 17, 18, 19, 20, 21, 25, 26, 27, 29, 30, 32]; HI=1;
# subnh=[1, 2 ,3 ,8, 9, 10, 14 ,16, 22 ,23, 24 ,28 ,31]# NH=0;Subject ID number and class labels; 
# # sub=[1,2]
# Ev=[1,2];#event number
# for k in range(0,len(subnh)):
#     for j in range(0,len(Ev)):
#         pnh=dirpath+'S'+str(sub[k])+'/'+'Event_'+str(Ev[j])+'/'
#         dpin=pnh
#         print dpin
#         from os import walk
#         from os.path import isfile, join
#         f = []
#         for (dpin, dirnames, filenames) in walk(dpin):
#             f.extend(join(dpin, x) for x in filenames if x.endswith(".csv"))
#             break
#         for i in range(0,len(f)):
#             dd=pd.read_csv(f[i])
#             dd1=dd.drop(dd.columns[0],axis=1)
#             a=a+dd1
#             count=count+1
#         dnhc=pd.DataFrame(a)
# #         d2.insert(0,'label',np.zeros(len(d2)), True)
#         # df.insert(2, "Age", [21, 23, 24, 21], True)
# # d2
# count

# %%
# dall=pd.concat([d2, dhi])

# %%
#  dall.to_csv('10ms_all_erp'+'.csv')

# %%
# df1.to_csv(fname+'.csv')
# t=np.linspace(-10,200,106)
# plt.plot(t,dnhc.iloc[50:52,:].values.T*1e9/count)
# plt.xlim(-10, 210)
# plt.grid(True)
# plt.show()

# %%
# plt.plot(t,dhic.iloc[1:4,:].T*1e9/count)
# plt.grid()
# plt.show()

# %%
dsp='/home/sultan/EEG/CP/CP_Source_data/S1/Trig_1/S1Trig1_t1.csv'
dd1=pd.read_csv(dsp)

# %%
# d1=dd1.iloc[0,1:]
# # plt.plot(t,dnhc.iloc[[36,40,48,66,67],:].values.T*1e9/count)
# plt.plot(t,d1*1e9)
# plt.xlim(-200, 800)
# plt.grid(True)
# plt.xlabel("Time (ms)")
# plt.ylabel("Voltage(nV)")
# plt.title("Combined 1 and 5 Trigers")
# # plt.legend('1','2')
# plt.show()

# %%
t=np.linspace(-200,800,500)
# plt.plot(t,dnhc.iloc[[36,37,40,41,48,49,66,67],:].values.T*1e9/count)
# plt.plot(t,dnhc.iloc[[36,40,48,66,67],:].values.T*1e9)
plt.plot(t,dd1.iloc[rois,1:].values.T*1e9)
plt.xlim(-200, 800)
plt.grid(True)
plt.xlabel("Time (ms)")
plt.ylabel("Voltage(nV)")
plt.title("single trial_trig_1")
# plt.legend('1','2')
plt.legend(leg)
plt.show()

# %%
# dd1

# %% [markdown]
# # Here is the 8 ROIs

# %%
# leg1=['lPOP','rPOP','lPT', 'rPT','lPRC','rPRC','lTRANS','rTRANS']
# rois1=[36,37,40,41,48,49,66,67]
# dd1.iloc[rois,:]
# Out:
#                      cc1           cc2           cc3           cc4  \
# 36     parsopercularis L -5.556799e-11 -3.103825e-11 -5.033683e-11
# 37     parsopercularis R -9.708106e-11 -8.622179e-11 -6.953990e-12
# 40    parstriangularis L -1.443690e-10 -6.628593e-11  4.944440e-12
# 41    parstriangularis R -1.924242e-10 -2.814919e-10 -2.117071e-10
# 48          precentral L -9.013169e-12 -7.871865e-12  2.250032e-11
# 49          precentral R  8.144651e-11  1.258447e-10  1.303797e-10
# 66  transversetemporal L  2.248301e-11  1.363724e-10  2.555569e-10
# 67  transversetemporal R -7.103009e-11 -2.122680e-10 -2.749378e-10
#
#              cc5           cc6           cc7           cc8           cc9  \
# 36 -8.071584e-11 -9.088271e-11 -1.178582e-10 -1.974336e-10 -2.943297e-10
# 37  8.276171e-11  1.079229e-10  8.564190e-11  5.210953e-11  1.141806e-11
# 40  6.459550e-11  1.038307e-10  1.145207e-10  1.197669e-10  1.513844e-10
# 41 -7.961054e-11 -7.046342e-11 -1.886366e-10 -2.953635e-10 -3.003368e-10
# 48  5.616656e-11  6.036602e-11  4.345097e-11  3.252898e-11  3.970894e-11
# 49  1.269833e-10  1.399562e-10  1.359497e-10  1.095437e-10  1.003614e-10
# 66  3.609892e-10  4.266940e-10  4.288304e-10  3.771080e-10  3.269669e-10
# 67 -2.816260e-10 -3.130640e-10 -3.658482e-10 -3.539829e-10 -2.511565e-10
#
#             cc10      ...              cc492         cc493         cc494  \
# 36 -3.519418e-10      ...       8.648827e-11  8.156946e-11  1.119755e-10
# 37 -3.963292e-11      ...       8.322152e-10  8.359854e-10  9.271052e-10
# 40  2.013860e-10      ...       4.566494e-10  4.560969e-10  4.888719e-10
# 41 -2.720985e-10      ...       3.521251e-10  3.493599e-10  4.611224e-10
# 48  5.088169e-11      ...       4.024329e-10  4.083131e-10  4.364825e-10
# 49  1.248710e-10      ...      -4.124946e-10 -4.665133e-10 -5.174864e-10
# 66  3.190506e-10      ...       7.431822e-10  7.683867e-10  8.366607e-10
# 67 -1.503503e-10      ...      -3.605808e-10 -3.280044e-10 -3.180456e-10
#
#            cc495         cc496         cc497         cc498         cc499  \
# 36  1.511527e-10  1.716891e-10  1.751873e-10  1.666220e-10  1.389458e-10
# 37  1.035987e-09  1.068025e-09  9.983393e-10  8.806937e-10  7.780278e-10
# 40  5.374919e-10  5.750058e-10  5.790446e-10  5.329665e-10  4.406799e-10
# 41  6.000657e-10  6.498225e-10  6.062790e-10  5.479263e-10  5.103031e-10
# 48  4.737937e-10  4.934674e-10  4.815054e-10  4.467700e-10  4.056990e-10
# 49 -5.598383e-10 -5.779114e-10 -5.510204e-10 -4.963616e-10 -4.473286e-10
# 66  8.923345e-10  8.970307e-10  8.516119e-10  7.738692e-10  6.841999e-10
# 67 -3.048317e-10 -2.841983e-10 -2.501204e-10 -1.868461e-10 -1.179603e-10
#
#            cc500         cc501
# 36  1.028565e-10  7.877320e-11
# 37  6.984870e-10  6.121033e-10
# 40  3.487178e-10  2.895420e-10
# 41  4.685957e-10  4.007556e-10
# 48  3.690779e-10  3.355317e-10
# 49 -3.989807e-10 -3.305068e-10
# 66  6.021934e-10  5.290653e-10
# 67 -8.821884e-11 -1.015740e-10
#
# [8 rows x 501 columns]

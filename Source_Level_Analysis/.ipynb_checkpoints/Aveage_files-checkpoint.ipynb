# %% [raw]
# import shutil, random, os
# import pandas as pd
# #import mne
# import matplotlib.pyplot as plt

# %%
# data directory
#dirpath="/home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S1/Event_1"
# destination directory
#destDirectory="/home/sultan/EEG/Source_Level_Analysis/Source_ERP"
sample=10;#Number of sample randomly select
filenames = random.sample(os.listdir(dirpath),sample)
for fname in filenames:
    srcpath = os.path.join(dirpath, fname)
    print srcpath
d= pd.read_csv(srcpath)
    #shutil.copyfile(srcpath, destDirectory)
# Out:
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t30.csv
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t23.csv
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t24.csv
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t17.csv
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t10.csv
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t29.csv
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t14.csv
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t13.csv
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t11.csv
# /home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t20.csv

# %%
# tmp = d.copy()
len(f)
# Out:
# 2999

# %%
dirpath="/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/"

# %%
#tmp.drop(columns=['cc1'] ) # drop the first column

# %%
from os import walk
from os.path import isfile, join

f = []
for (dirpath, dirnames, filenames) in walk(dirpath):
    f.extend(join(dirpath, x) for x in filenames if x.endswith(".csv"))
    break

# %%
f
# Out:
# ['/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t22.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t16.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t21.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t26.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t17.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t15.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t7.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t4.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t28.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t5.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t14.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t27.csv',
#  '/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/S1event1_t29.csv',
# ...

# %%
sample=10;
totalchunk = len(f) / sample 
print (totalchunk)
# test purpose 
# totalchunk = 2
import numpy as np
for i in range(totalchunk): # we will generate two at a time
    mychunk = np.random.choice(f,size=sample,replace=False)
    #print mychunk
    # make sure the chunk element does not exist in the original list 
    f = list(set(f) - set(mychunk))
#     print len(f)
    doAvgSave(mychunk)
# Out:
# 3

# %%
def doAvgSave(chunk):
    df1 = pd.read_csv(chunk[0])
    tmp = df1.copy()
    tmp = tmp.drop(columns=['cc1'] )
    for i in range(1,len(chunk)):
        tmp1 = pd.read_csv(chunk[i])
        tmp1 = tmp1.drop(columns=['cc1'] )
        tmp = tmp + tmp1 # add those     
    tmp = tmp.div( len(chunk)) # average 
    df1.update(tmp) # this is the new data frame with average 
    # write to some location 
# print tmp

# %%
plt.plot(tmp.iloc[8,1:].values)
plt.show()

# %%
len(tmp.iloc[2,:].values)
# Out:
# 107

# %%
plt.plot(d.iloc[8,1:].T)
plt.show()

# %%
plt.plot((tmp.iloc[1:3,1:].T))
plt.show()

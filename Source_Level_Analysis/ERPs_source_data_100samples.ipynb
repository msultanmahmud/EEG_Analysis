# %%
import shutil, random, os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# This is small data set path for testing purpose
# dirpath="/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/"
#dirpath="/home/sultan/EEG/Source_Level_Analysis/test_csv_evoke/"
# dirpath="/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/"
#dirpath='/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_1/'
dirpath='/home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/'
# dirpath='/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_1/S1/Event_1/'
# despath="/home/sultan/EEG/Source_Level_Analysis/100sample10ms/"
despath="/home/sultan/EEG/Source_Level_Analysis/100sample_ERPs/"
# despath="/home/sultan/EEG/Source_Level_Analysis/75sample10mswind/"
sample=100

# %% [markdown]
# # Function for averaging the trial

# %%
# def doAvgSave(chunk,fname):
#     df1 = pd.read_csv(chunk[0])
#     tmp = df1.copy()
#     tmp = tmp.drop(columns=['cc1'] )
#     #print tmp
#     for c in range(1,len(chunk)):
#         tmp1 = pd.read_csv(chunk[c])
#         tmp1 = tmp1.drop(columns=['cc1'] )
#         tmp = tmp + tmp1 # add those
#         #print chunk[i]
#     tmpd = tmp.div(len(chunk)) # average
# #     plt.plot(tmp.iloc[8,1:].values)
# #     plt.grid(True)
# #     plt.show()

#     df1.update(tmpd) # this is the new data frame with average 
#     # write to some location 
#     #df1.to_csv(fname+'.csv')
    
#     j2=0; k2=5; ad=[];
#     for i2 in range(0,21):
# #         print i2
#         da=tmpd.iloc[:,j2:k2]
# #     print j,k
#         j2=j2+5; k2=k2+5
#         ax=da.mean(axis=1)
#         ad.append(ax)
#     ddrf=pd.DataFrame(ad)
#     dtr=ddrf.T
# #     print dtr
#     dtr.to_csv(fname+''+'.csv')
# #     df1.to_csv(fname+'.csv')
# #     t=np.linspace(-10,200,106)
# #     plt.plot(t,df1.iloc[3:5,1:].values.T*1e9)
# #     plt.xlim(-10, 210)
# #     plt.grid(True)
# #     plt.show()

# %% [markdown]
# # Read the csv file and feed to the function

# %%
# dirpath="/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/"
# # dirpath='/home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/'
# despath="/home/sultan/EEG/Source_Level_Analysis/100sample_ERPs/"

# %%
def doAvgSave(chunk,fname):
    df1 = pd.read_csv(chunk[0])
    tmp = df1.copy()
    tmp = tmp.drop(columns=['cc1'] )
    #print tmp
    for c in range(1,len(chunk)):
        tmp1 = pd.read_csv(chunk[c])
        tmp1 = tmp1.drop(columns=['cc1'] )
        tmp = tmp + tmp1 # add those
        #print chunk[i]
    tmpd = tmp.div(len(chunk)) # average
#     plt.plot(tmp.iloc[8,1:].values)
#     plt.grid(True)
#     plt.show()

    df1.update(tmpd) # this is the new data frame with average 
# #     print dtr
#     print df1
    df1.to_csv(fname+''+'.csv')
    #dtr.to_csv(fname+''+'.csv')
# #     df1.to_csv(fname+'.csv')
# #     t=np.linspace(-10,200,106)
# #     plt.plot(t,df1.iloc[3:5,1:].values.T*1e9)
# #     plt.xlim(-10, 210)
# #     plt.grid(True)
    plt.show()

# %%
sub=33;# subject+1
Ev=5;#event+1
# sample=75;# How many samples need to average out
for k in range(1,sub):
    for j in range(1,Ev):
        b=dirpath+'S'+str(k)+'/'+'Event_'+str(j)+'/'
        dpin=b
        print dpin
        from os import walk
        from os.path import isfile, join
        f = []
        for (dpin, dirnames, filenames) in walk(dpin):
            f.extend(join(dpin, x) for x in filenames if x.endswith(".csv"))
            break
        #print f
#         sample=100;# How many samples need to average out
        totalchunk = len(f) / sample 
        print (totalchunk)
        # test purpose 
        # totalchunk = 2
        descr=despath+'S'+str(k)+'/'+'Event_'+str(j); # Make directory 
        os.makedirs(descr)
        import numpy as np
        for i in range(totalchunk): # we will generate two at a time
            mychunk = np.random.choice(f,size=sample,replace=False)
            #print mychunk
            # make sure the chunk element does not exist in the original list 
            f = list(set(f) - set(mychunk))
            #print f
            #fname=descr+'Av'+str(i)
            #fname='S'+str(k)+'event'+str(j)+'av'+str(i)
            fname=despath+'S'+str(k)+'/'+'Event_'+str(j)+'/'+'S'+str(k)+'event'+str(j)+'_'+str(sample)+'erp'+str(i)
            doAvgSave(mychunk,fname)
# Out:
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S1/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S1/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S1/Event_3/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S1/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S2/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S2/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S2/Event_3/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S2/Event_4/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S3/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S3/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S3/Event_3/
# 19
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S3/Event_4/
# 19
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S4/Event_1/
# 19
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S4/Event_2/
# 19
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S4/Event_3/
# 19
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S4/Event_4/
# 19
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S5/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S5/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S5/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S5/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S6/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S6/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S6/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S6/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S7/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S7/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S7/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S7/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S8/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S8/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S8/Event_3/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S8/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S9/Event_1/
# 39
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S9/Event_2/
# 39
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S9/Event_3/
# 19
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S9/Event_4/
# 19
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S10/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S10/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S10/Event_3/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S10/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S11/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S11/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S11/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S11/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S12/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S12/Event_2/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S12/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S12/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S13/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S13/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S13/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S13/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S14/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S14/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S14/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S14/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S15/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S15/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S15/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S15/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S16/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S16/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S16/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S16/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S17/Event_1/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S17/Event_2/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S17/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S17/Event_4/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S18/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S18/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S18/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S18/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S19/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S19/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S19/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S19/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S20/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S20/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S20/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S20/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S21/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S21/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S21/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S21/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S22/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S22/Event_2/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S22/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S22/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S23/Event_1/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S23/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S23/Event_3/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S23/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S24/Event_1/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S24/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S24/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S24/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S25/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S25/Event_2/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S25/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S25/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S26/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S26/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S26/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S26/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S27/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S27/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S27/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S27/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S28/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S28/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S28/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S28/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S29/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S29/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S29/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S29/Event_4/
# 30
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S30/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S30/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S30/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S30/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S31/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S31/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S31/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S31/Event_4/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S32/Event_1/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S32/Event_2/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S32/Event_3/
# 29
# /home/sultan/EEG/Source_Level_Analysis/Extracted_CSV_Source_Dk_data/S32/Event_4/
# 29

# %%
descr=despath+'S'+str(k)+'/'+'Event_'+str(j)+'/'+'S'+str(k)+'event'+str(j)+'_av'+str(i)
descr
# Out:
# '/home/sultan/EEG/Source_Level_Analysis/100sample_ERPs/S32/Event_4/S32event4_av28'

# %%
fname+'.csv'
# Out:
# '/home/sultan/EEG/Source_Level_Analysis/100sample_ERPs/S32/Event_4/S32event4_100erp28.csv'

# %%
tmpd
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-9-d03e5d8834bb> in <module>()
# ----> 1 tmpd
#
# NameError: name 'tmpd' is not defined

# %%
# dirpath='/home/sultan/EEG/Source_Level_Analysis/Source_ERP/Small_data_test/S1/Event_1/'

# %%
# from os import walk
# from os.path import isfile, join
# f = []
# for (dirpath, dirnames, filenames) in walk(dirpath):
#     f.extend(join(dirpath, x) for x in filenames if x.endswith(".csv"))
#     break

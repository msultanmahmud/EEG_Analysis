# %% [markdown]
# ## Noise band frequency

# %%
import numpy as np
import pandas as pd
from sklearn import svm, metrics,preprocessing
#from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve, auc,classification_report
from matplotlib import pyplot as plt
from collections import Counter
from scipy.stats import norm
# import seaborn as sns; sns.set(font_scale=1.2)
# %matplotlib inline

# %%
# path='/home/sultan/EEG/Source_Level_Analysis/25sam_10ms_clear_all_erp.csv'
# path='/home/sultan/EEG/Source_Level_Analysis/50tr10ms_all_clear_erp.csv'
# path="/home/sultan/EEG/Source_Level_Analysis/75sam_10ms_clear_all_erp.csv"
# path="/home/sultan/EEG/Source_Level_Analysis/100sam_10ms_clear_all_erp.csv"
#path="/home/sultan/EEG/Source_Level_Analysis/Baseline_100sam_10ms_clear_all_erp.csv"
path="/home/sultan/EEG/Source_Level_Analysis/Baseline_100sam_10ms_noise_all_erp.csv"
dataset =pd.read_csv(path)

# %%
rs=47;
parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100],'gamma':[0.01,0.0147, 0.016, 0.019,0.029]}

# %%
Xc=dataset.iloc[:,2:].values
y=dataset.iloc[:,1].values
scaler = preprocessing.StandardScaler()
X = scaler.fit_transform(Xc)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.20, random_state=rs)

# %%
X_test.shape, y_test.shape
# Out:
# ((361, 1428), (361,))

# %%
np.unique(y_test)
np.unique(y_test,return_counts=True)
# Out:
# (array([0., 1.]), array([148, 213]))

# %% [markdown]
# # Whole brain

# %%
nstep=(X_train.shape[1]/68)
k=0;j=68; acgw=[];pmw=[];aucw=[];
for i in range(0,nstep):
    cv=5
#     from sklearn.model_selection import GridSearchCV
#     parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100,1000],'gamma':[0.01,0.0147, 0.016, 0.019, 0.021]}
    svc = svm.SVC()
    clf = GridSearchCV(svc, parameters,cv=cv)
    clf.fit(X_train[:,k:j], y_train)
    pred=clf.best_estimator_.predict(X_test[:,k:j])
    acc=clf.score(X_test[:,k:j], y_test)
    acgw=np.append(acgw,acc)
    print (i*10);
    print ("Accuracy:",acc)
    perf=classification_report(y_test, pred)
    pmw.append(perf)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,pred)
    roc_auc=metrics.auc(fpr, tpr)
    roc_auc
    aucw.append(roc_auc)
    print ("ROC", roc_auc)
    print (perf)
    print (k,j)
    k=k+68;j=j+68;
    print clf.best_estimator_
#     scores=clf.cv_results_['mean_test_score']
#     print("Accuracy:%0.3f (+/-%0.3f)" %(scores.mean(), scores.std()*2))
# Out:
# 0
# ('Accuracy:', 0.590027700831025)
# ('ROC', 0.5)
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00       148
#         1.0       0.59      1.00      0.74       213
#
# avg / total       0.35      0.59      0.44       361
#
# (0, 68)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 10
# ('Accuracy:', 0.7063711911357341)
# ('ROC', 0.6831303134120036)
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.55      0.61       148
#         1.0       0.72      0.81      0.77       213
#
# avg / total       0.70      0.71      0.70       361
#
# (68, 136)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.029, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 20
# ('Accuracy:', 0.6731301939058172)
# ('ROC', 0.6508374571754852)
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.53      0.57       148
#         1.0       0.70      0.77      0.74       213
#
# avg / total       0.67      0.67      0.67       361
#
# (136, 204)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.016, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 30
# ('Accuracy:', 0.739612188365651)
# ('ROC', 0.723670853952544)
#              precision    recall  f1-score   support
#
#         0.0       0.70      0.64      0.67       148
#         1.0       0.76      0.81      0.79       213
#
# avg / total       0.74      0.74      0.74       361
#
# (204, 272)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.019, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 40
# ('Accuracy:', 0.7257617728531855)
# ('ROC', 0.7057480015226494)
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.59      0.64       148
#         1.0       0.74      0.82      0.78       213
#
# avg / total       0.72      0.73      0.72       361
#
# (272, 340)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.029, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 50
# ('Accuracy:', 0.7479224376731302)
# ('ROC', 0.7276202258596626)
#              precision    recall  f1-score   support
#
#         0.0       0.73      0.61      0.67       148
#         1.0       0.76      0.84      0.80       213
#
# avg / total       0.75      0.75      0.74       361
#
# (340, 408)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.029, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 60
# ('Accuracy:', 0.7451523545706371)
# ('ROC', 0.7448610582413399)
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.74      0.71       148
#         1.0       0.81      0.75      0.78       213
#
# avg / total       0.75      0.75      0.75       361
#
# (408, 476)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.016, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 70
# ('Accuracy:', 0.7229916897506925)
# ('ROC', 0.7147411496003044)
#              precision    recall  f1-score   support
#
#         0.0       0.66      0.67      0.66       148
#         1.0       0.77      0.76      0.76       213
#
# avg / total       0.72      0.72      0.72       361
#
# (476, 544)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 80
# ('Accuracy:', 0.7811634349030471)
# ('ROC', 0.7764084507042254)
#              precision    recall  f1-score   support
#
#         0.0       0.73      0.75      0.74       148
#         1.0       0.82      0.80      0.81       213
#
# avg / total       0.78      0.78      0.78       361
#
# (544, 612)
# SVC(C=70, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 90
# ('Accuracy:', 0.739612188365651)
# ('ROC', 0.7339804593325719)
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.70      0.69       148
#         1.0       0.79      0.77      0.78       213
#
# avg / total       0.74      0.74      0.74       361
#
# (612, 680)
# SVC(C=20, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 100
# ('Accuracy:', 0.7534626038781164)
# ('ROC', 0.7580890749904834)
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.78      0.72       148
#         1.0       0.83      0.73      0.78       213
#
# avg / total       0.76      0.75      0.76       361
#
# (680, 748)
# SVC(C=20, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 110
# ('Accuracy:', 0.7673130193905817)
# ('ROC', 0.7595165588123335)
#              precision    recall  f1-score   support
#
#         0.0       0.72      0.72      0.72       148
#         1.0       0.80      0.80      0.80       213
#
# avg / total       0.77      0.77      0.77       361
#
# (748, 816)
# SVC(C=30, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 120
# ('Accuracy:', 0.7451523545706371)
# ('ROC', 0.7417681766273316)
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.72      0.70       148
#         1.0       0.80      0.76      0.78       213
#
# avg / total       0.75      0.75      0.75       361
#
# (816, 884)
# SVC(C=20, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 130
# ('Accuracy:', 0.7645429362880887)
# ('ROC', 0.7654168252759802)
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.77      0.73       148
#         1.0       0.83      0.76      0.79       213
#
# avg / total       0.77      0.76      0.77       361
#
# (884, 952)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 140
# ('Accuracy:', 0.7368421052631579)
# ('ROC', 0.733694962568202)
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.72      0.69       148
#         1.0       0.79      0.75      0.77       213
#
# avg / total       0.74      0.74      0.74       361
#
# (952, 1020)
# SVC(C=40, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 150
# ('Accuracy:', 0.7728531855955678)
# ('ROC', 0.7662733155690902)
#              precision    recall  f1-score   support
#
#         0.0       0.72      0.73      0.72       148
#         1.0       0.81      0.80      0.81       213
#
# avg / total       0.77      0.77      0.77       361
#
# (1020, 1088)
# SVC(C=40, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 160
# ('Accuracy:', 0.7285318559556787)
# ('ROC', 0.7266527090470752)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.72      0.68       148
#         1.0       0.79      0.74      0.76       213
#
# avg / total       0.73      0.73      0.73       361
#
# (1088, 1156)
# SVC(C=20, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 170
# ('Accuracy:', 0.7202216066481995)
# ('ROC', 0.7123937317599289)
#              precision    recall  f1-score   support
#
#         0.0       0.66      0.67      0.66       148
#         1.0       0.77      0.76      0.76       213
#
# avg / total       0.72      0.72      0.72       361
#
# (1156, 1224)
# SVC(C=20, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.019, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 180
# ('Accuracy:', 0.7534626038781164)
# ('ROC', 0.7498413906864612)
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.73      0.71       148
#         1.0       0.80      0.77      0.79       213
#
# avg / total       0.76      0.75      0.75       361
#
# (1224, 1292)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 190
# ('Accuracy:', 0.7119113573407202)
# ('ROC', 0.7043205177007994)
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.66      0.65       148
#         1.0       0.76      0.75      0.75       213
#
# avg / total       0.71      0.71      0.71       361
#
# (1292, 1360)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 200
# ('Accuracy:', 0.7257617728531855)
# ('ROC', 0.7243052912066996)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.72      0.68       148
#         1.0       0.79      0.73      0.76       213
#
# avg / total       0.73      0.73      0.73       361
#
# (1360, 1428)
# SVC(C=30, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# # Hemisphrere analysis

# %% [markdown]
# ## RH

# %%
# only 34 features 
# parameters = {'kernel':['rbf'], 'C':[1, 10,20,30,70, 90,100,1000],'gamma':[0.015,0.025, 0.029, 0.030,2/5508.0,1/5508.0]}
a=range(0,(X.shape[1]),2)
d11=X[:,a];
X_train, X_test, y_train, y_test = train_test_split(d11,y, test_size=.20, random_state=rs) 
svc = svm.SVC()
k=0;j=34; acgr=[];aucrh=[];pmrh=[];
for i in range(0,nstep):
    cv=5
#     from sklearn.model_selection import GridSearchCV
#     parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100,1000],'gamma':[0.015,0.025, 0.029, 0.030,0.035]}
#     parameters = {'kernel':['rbf'], 'C':[1, 10,100,1000],'gamma':[0.01,2/1428.0,1/1428.0]}
    svc = svm.SVC()
    clf = GridSearchCV(svc, parameters,cv=cv)
    clf.fit(X_train[:,k:j], y_train)
    pred=clf.best_estimator_.predict(X_test[:,k:j])
    acc=clf.score(X_test[:,k:j], y_test)
    acgr=np.append(acgr,acc)
    print (i*10)
    print ("Accuracy:", acc)
    perf=classification_report(y_test, pred)
    pmrh.append(perf)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,pred)
    roc_auc=metrics.auc(fpr, tpr)
    roc_auc
    aucrh.append(roc_auc)
    print ("ROC:", roc_auc)
    print (perf)
#     print("Con:",confusion_matrix(y_test, pred))
    print (k,j)
    k=k+34;j=j+34;
    print clf.best_estimator_
# Out:
# 0
# ('Accuracy:', 0.590027700831025)
# ('ROC:', 0.5)
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00       148
#         1.0       0.59      1.00      0.74       213
#
# avg / total       0.35      0.59      0.44       361
#
# (0, 34)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 10
# ('Accuracy:', 0.7119113573407202)
# ('ROC:', 0.7074133993148077)
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.68      0.66       148
#         1.0       0.77      0.73      0.75       213
#
# avg / total       0.72      0.71      0.71       361
#
# (34, 68)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.019, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 20
# ('Accuracy:', 0.6592797783933518)
# ('ROC:', 0.6391003679736074)
#              precision    recall  f1-score   support
#
#         0.0       0.60      0.53      0.56       148
#         1.0       0.70      0.75      0.72       213
#
# avg / total       0.65      0.66      0.66       361
#
# (68, 102)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.029, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 30
# ('Accuracy:', 0.7229916897506925)
# ('ROC:', 0.727112676056338)
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.75      0.69       148
#         1.0       0.80      0.70      0.75       213
#
# avg / total       0.73      0.72      0.73       361
#
# (102, 136)
# SVC(C=30, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 40
# ('Accuracy:', 0.7146814404432132)
# ('ROC:', 0.6973892906991498)
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.60      0.63       148
#         1.0       0.74      0.79      0.77       213
#
# avg / total       0.71      0.71      0.71       361
#
# (136, 170)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.029, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 50
# ('Accuracy:', 0.7368421052631579)
# ('ROC:', 0.733694962568202)
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.72      0.69       148
#         1.0       0.79      0.75      0.77       213
#
# avg / total       0.74      0.74      0.74       361
#
# (170, 204)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.016, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 60
# ('Accuracy:', 0.739612188365651)
# ('ROC:', 0.7463519857886055)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.78      0.71       148
#         1.0       0.83      0.71      0.76       213
#
# avg / total       0.75      0.74      0.74       361
#
# (204, 238)
# SVC(C=40, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 70
# ('Accuracy:', 0.6648199445983379)
# ('ROC:', 0.6602905722624033)
#              precision    recall  f1-score   support
#
#         0.0       0.58      0.64      0.61       148
#         1.0       0.73      0.69      0.71       213
#
# avg / total       0.67      0.66      0.67       361
#
# (238, 272)
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 80
# ('Accuracy:', 0.6869806094182825)
# ('ROC:', 0.6904104809034386)
#              precision    recall  f1-score   support
#
#         0.0       0.60      0.71      0.65       148
#         1.0       0.77      0.67      0.72       213
#
# avg / total       0.70      0.69      0.69       361
#
# (272, 306)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.016, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 90
# ('Accuracy:', 0.7091412742382271)
# ('ROC:', 0.7009421393224211)
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.66      0.65       148
#         1.0       0.76      0.75      0.75       213
#
# avg / total       0.71      0.71      0.71       361
#
# (306, 340)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.016, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 100
# ('Accuracy:', 0.7285318559556787)
# ('ROC:', 0.7307765511990862)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.74      0.69       148
#         1.0       0.80      0.72      0.76       213
#
# avg / total       0.74      0.73      0.73       361
#
# (340, 374)
# SVC(C=90, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 110
# ('Accuracy:', 0.7285318559556787)
# ('ROC:', 0.7266527090470752)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.72      0.68       148
#         1.0       0.79      0.74      0.76       213
#
# avg / total       0.73      0.73      0.73       361
#
# (374, 408)
# SVC(C=30, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 120
# ('Accuracy:', 0.7534626038781164)
# ('ROC:', 0.7519033117624666)
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.74      0.71       148
#         1.0       0.81      0.76      0.78       213
#
# avg / total       0.76      0.75      0.75       361
#
# (408, 442)
# SVC(C=40, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 130
# ('Accuracy:', 0.7229916897506925)
# ('ROC:', 0.7291745971323436)
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.76      0.69       148
#         1.0       0.81      0.69      0.75       213
#
# avg / total       0.74      0.72      0.73       361
#
# (442, 476)
# SVC(C=30, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 140
# ('Accuracy:', 0.6952908587257618)
# ('ROC:', 0.699514655500571)
#              precision    recall  f1-score   support
#
#         0.0       0.61      0.72      0.66       148
#         1.0       0.78      0.68      0.72       213
#
# avg / total       0.71      0.70      0.70       361
#
# (476, 510)
# SVC(C=70, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 150
# ('Accuracy:', 0.7229916897506925)
# ('ROC:', 0.7188649917523158)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.70      0.67       148
#         1.0       0.78      0.74      0.76       213
#
# avg / total       0.73      0.72      0.72       361
#
# (510, 544)
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 160
# ('Accuracy:', 0.6648199445983379)
# ('ROC:', 0.6633834538764117)
#              precision    recall  f1-score   support
#
#         0.0       0.58      0.66      0.62       148
#         1.0       0.74      0.67      0.70       213
#
# avg / total       0.67      0.66      0.67       361
#
# (544, 578)
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 170
# ('Accuracy:', 0.7119113573407202)
# ('ROC:', 0.7125682020048217)
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.72      0.67       148
#         1.0       0.78      0.71      0.74       213
#
# avg / total       0.72      0.71      0.71       361
#
# (578, 612)
# SVC(C=70, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 180
# ('Accuracy:', 0.7285318559556787)
# ('ROC:', 0.7297455906610836)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.74      0.69       148
#         1.0       0.80      0.72      0.76       213
#
# avg / total       0.74      0.73      0.73       361
#
# (612, 646)
# SVC(C=70, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 190
# ('Accuracy:', 0.7174515235457064)
# ('ROC:', 0.7213868798375841)
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.74      0.68       148
#         1.0       0.80      0.70      0.74       213
#
# avg / total       0.73      0.72      0.72       361
#
# (646, 680)
# SVC(C=70, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 200
# ('Accuracy:', 0.7229916897506925)
# ('ROC:', 0.7260817155183352)
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.74      0.69       148
#         1.0       0.80      0.71      0.75       213
#
# avg / total       0.73      0.72      0.73       361
#
# (680, 714)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# # LH

# %%
b=range(1,(X.shape[1]),2)
d22=X[:,b];
X_train, X_test, y_train, y_test = train_test_split(d22,y, test_size=.20, random_state=rs) 
k=0;j=34; acgl=[];auclh=[];pmlh=[];
for i in range(0,nstep):
    cv=5
#     from sklearn.model_selection import GridSearchCV
#     parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100,1000],'gamma':[0.015,0.025, 0.029, 0.030,0.035]} 
#     parameters = {'kernel':['rbf'], 'C':[1, 10,100,1000],'gamma':[0.01,2/1428.0,1/1428.0]}
#     parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100,1000],'gamma':[0.015,0.025, 0.029, 0.030,0.035]}
    svc = svm.SVC()
    clf = GridSearchCV(svc, parameters,cv=cv)
    clf.fit(X_train[:,k:j], y_train)
    pred=clf.best_estimator_.predict(X_test[:,k:j])
    acc=clf.score(X_test[:,k:j], y_test)
    acgl=np.append(acgl,acc)
    print (i*10)
    print ("Accuracy:", acc)
    perf=classification_report(y_test, pred)
    pmlh.append(perf)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,pred)
    roc_auc=metrics.auc(fpr, tpr)
    roc_auc
    auclh.append(roc_auc)
    print ("ROC:", roc_auc)
    print perf
#     print("Con:",confusion_matrix(y_test, pred))
    print (k,j)
    k=k+34;j=j+34;
    print clf.best_estimator_
# Out:
# 0
# ('Accuracy:', 0.590027700831025)
# ('ROC:', 0.5)
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00       148
#         1.0       0.59      1.00      0.74       213
#
# avg / total       0.35      0.59      0.44       361
#
# (0, 34)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 10
# ('Accuracy:', 0.6620498614958449)
# ('ROC:', 0.6424787463519858)
#              precision    recall  f1-score   support
#
#         0.0       0.60      0.53      0.56       148
#         1.0       0.70      0.75      0.72       213
#
# avg / total       0.66      0.66      0.66       361
#
# (34, 68)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.029, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 20
# ('Accuracy:', 0.6814404432132964)
# ('ROC:', 0.6568487501586093)
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.52      0.57       148
#         1.0       0.70      0.79      0.75       213
#
# avg / total       0.68      0.68      0.67       361
#
# (68, 102)
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.029, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 30
# ('Accuracy:', 0.6869806094182825)
# ('ROC:', 0.6811318360614136)
#              precision    recall  f1-score   support
#
#         0.0       0.61      0.65      0.63       148
#         1.0       0.75      0.71      0.73       213
#
# avg / total       0.69      0.69      0.69       361
#
# (102, 136)
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 40
# ('Accuracy:', 0.703601108033241)
# ('ROC:', 0.6952163431036671)
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.65      0.64       148
#         1.0       0.75      0.74      0.75       213
#
# avg / total       0.70      0.70      0.70       361
#
# (136, 170)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.016, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 50
# ('Accuracy:', 0.7146814404432132)
# ('ROC:', 0.7076988960791777)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.67      0.66       148
#         1.0       0.76      0.75      0.76       213
#
# avg / total       0.72      0.71      0.72       361
#
# (170, 204)
# SVC(C=40, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 60
# ('Accuracy:', 0.7091412742382271)
# ('ROC:', 0.7081588630884404)
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.70      0.66       148
#         1.0       0.78      0.71      0.74       213
#
# avg / total       0.72      0.71      0.71       361
#
# (204, 238)
# SVC(C=20, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 70
# ('Accuracy:', 0.703601108033241)
# ('ROC:', 0.7034640274076892)
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.70      0.66       148
#         1.0       0.77      0.70      0.74       213
#
# avg / total       0.71      0.70      0.71       361
#
# (238, 272)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.016, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 80
# ('Accuracy:', 0.7257617728531855)
# ('ROC:', 0.7263672122827052)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.73      0.69       148
#         1.0       0.79      0.72      0.76       213
#
# avg / total       0.73      0.73      0.73       361
#
# (272, 306)
# SVC(C=40, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.016, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 90
# ('Accuracy:', 0.6814404432132964)
# ('ROC:', 0.6764370003806623)
#              precision    recall  f1-score   support
#
#         0.0       0.60      0.65      0.63       148
#         1.0       0.74      0.70      0.72       213
#
# avg / total       0.69      0.68      0.68       361
#
# (306, 340)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.019, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 100
# ('Accuracy:', 0.7285318559556787)
# ('ROC:', 0.7349003933510976)
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.77      0.70       148
#         1.0       0.81      0.70      0.75       213
#
# avg / total       0.74      0.73      0.73       361
#
# (340, 374)
# SVC(C=90, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 110
# ('Accuracy:', 0.7368421052631579)
# ('ROC:', 0.7275091993401853)
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.68      0.68       148
#         1.0       0.78      0.78      0.78       213
#
# avg / total       0.74      0.74      0.74       361
#
# (374, 408)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.029, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 120
# ('Accuracy:', 0.7091412742382271)
# ('ROC:', 0.7081588630884404)
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.70      0.66       148
#         1.0       0.78      0.71      0.74       213
#
# avg / total       0.72      0.71      0.71       361
#
# (408, 442)
# SVC(C=50, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 130
# ('Accuracy:', 0.7146814404432132)
# ('ROC:', 0.7149156198451974)
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.72      0.67       148
#         1.0       0.78      0.71      0.75       213
#
# avg / total       0.72      0.71      0.72       361
#
# (442, 476)
# SVC(C=20, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 140
# ('Accuracy:', 0.6952908587257618)
# ('ROC:', 0.6830192868925263)
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.61      0.62       148
#         1.0       0.74      0.75      0.74       213
#
# avg / total       0.69      0.70      0.69       361
#
# (476, 510)
# SVC(C=40, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.029, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 150
# ('Accuracy:', 0.703601108033241)
# ('ROC:', 0.6962473036416699)
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.66      0.64       148
#         1.0       0.75      0.74      0.75       213
#
# avg / total       0.71      0.70      0.70       361
#
# (510, 544)
# SVC(C=40, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 160
# ('Accuracy:', 0.7146814404432132)
# ('ROC:', 0.7056369750031722)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.66      0.65       148
#         1.0       0.76      0.76      0.76       213
#
# avg / total       0.71      0.71      0.71       361
#
# (544, 578)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 170
# ('Accuracy:', 0.7202216066481995)
# ('ROC:', 0.7175485344499428)
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.70      0.67       148
#         1.0       0.78      0.73      0.76       213
#
# avg / total       0.73      0.72      0.72       361
#
# (578, 612)
# SVC(C=30, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 180
# ('Accuracy:', 0.7728531855955678)
# ('ROC:', 0.7693661971830985)
#              precision    recall  f1-score   support
#
#         0.0       0.71      0.75      0.73       148
#         1.0       0.82      0.79      0.80       213
#
# avg / total       0.78      0.77      0.77       361
#
# (612, 646)
# SVC(C=90, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0147, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 190
# ('Accuracy:', 0.6897506925207756)
# ('ROC:', 0.684510214439792)
#              precision    recall  f1-score   support
#
#         0.0       0.61      0.66      0.63       148
#         1.0       0.75      0.71      0.73       213
#
# avg / total       0.69      0.69      0.69       361
#
# (646, 680)
# SVC(C=90, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 200
# ('Accuracy:', 0.6952908587257618)
# ('ROC:', 0.6881740895825403)
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.65      0.64       148
#         1.0       0.75      0.73      0.74       213
#
# avg / total       0.70      0.70      0.70       361
#
# (680, 714)
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
t=np.linspace(0,200,21, endpoint=True)
time=pd.DataFrame(t)
# a=pd.concat([time,pd.DataFrame(acgw),pd.DataFrame(acgl),pd.DataFrame(acgr)],axis=1, keys=[ 'time',"Whole", "LH", "RH"])
a=pd.concat([time,pd.DataFrame(acgw),pd.DataFrame(acgl),pd.DataFrame(acgr)],axis=1, keys=[ 'time',"Whole", "LH", "RH"])

# %%
np.max(a)
# Out:
# time   0    200.000000
# Whole  0      0.781163
# LH     0      0.772853
# RH     0      0.753463
# dtype: float64

# %%
a
# Out:
#      time     Whole        LH        RH
#         0         0         0         0
# 0     0.0  0.590028  0.590028  0.590028
# 1    10.0  0.706371  0.662050  0.711911
# 2    20.0  0.673130  0.681440  0.659280
# 3    30.0  0.739612  0.686981  0.722992
# 4    40.0  0.725762  0.703601  0.714681
# 5    50.0  0.747922  0.714681  0.736842
# 6    60.0  0.745152  0.709141  0.739612
# 7    70.0  0.722992  0.703601  0.664820
# 8    80.0  0.781163  0.725762  0.686981
# 9    90.0  0.739612  0.681440  0.709141
# 10  100.0  0.753463  0.728532  0.728532
# 11  110.0  0.767313  0.736842  0.728532
# 12  120.0  0.745152  0.709141  0.753463
# 13  130.0  0.764543  0.714681  0.722992
# 14  140.0  0.736842  0.695291  0.695291
# 15  150.0  0.772853  0.703601  0.722992
# 16  160.0  0.728532  0.714681  0.664820
# 17  170.0  0.720222  0.720222  0.711911
# 18  180.0  0.753463  0.772853  0.728532
# 19  190.0  0.711911  0.689751  0.717452
# 20  200.0  0.725762  0.695291  0.722992

# %%
a

# %% [markdown]
# # Writing the csv data all

# %%
# wpath="/home/sultan/EEG/Source_Level_Analysis/SVM_results/"
# dall=a
# dall.to_csv(wpath+'svm_baseline_100sam_10ms_noise_v47.csv')
wpath+'svm_baseline_100sam_10ms_noise_v47.csv'

# %%
axis_font = {'fontname':'Arial', 'size':'15'}
#tw1=tad.iloc[1:,0];Acdw1=tad.iloc[1:,1];
tw1=a.iloc[0:,0];Acdw=a.iloc[0:,1];Acdlh=a.iloc[0:,2];Acdrh=a.iloc[0:,3]
# plt.plot(tw1,Acdw1,c='g')
plt.plot(tw1,Acdw,'g',linewidth=2,marker='*')
plt.plot(tw1, Acdlh,'--r',linewidth=2,marker='o')
plt.plot(tw1, Acdrh,'--b',linewidth=2,marker='x')
plt.title("100ms_10ms_noise")
plt.xlim(0,200)
# plt.plot(tw1,Acdw1, 'k--', label='noise')
# plt.xlabel('Time (ms)',**axis_font)
# plt.ylabel('Accuracy (%)',**axis_font)
# plt.title('Whole brain',**axis_font)
# plt.yticks(**axis_font)
# plt.xticks(**axis_font)
plt.grid(True)
plt.tight_layout()
plt.gca().legend(('Whole','LH','RH'),fontsize=16,loc='best')
# plt.savefig('whole_acc_timem.eps')
# plt.savefig('whole_acc_timem.tif')
plt.show()

# %% [markdown]
# # STOPPPPPPPPPPPPPP

# %%
X_train.shape

# %%
# wpath="/home/sultan/EEG/Source_Level_Analysis/SVM_results/"
# dall=a
# dall.to_csv(wpath+'svm_res_100sam_10ms_clear_v2.csv')

# %%
2.0/68
rs

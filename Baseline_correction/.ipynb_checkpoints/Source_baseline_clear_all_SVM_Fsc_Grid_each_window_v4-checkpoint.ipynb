# %%
import numpy as np
import pandas as pd
from sklearn import svm, metrics,preprocessing
#from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve, auc,classification_report
from matplotlib import pyplot as plt
from collections import Counter
from scipy.stats import norm
# import seaborn as sns; sns.set(font_scale=1.2)
# %matplotlib inline

# %%
# path='/home/sultan/EEG/Source_Level_Analysis/25sam_10ms_clear_all_erp.csv'
#path="/home/sultan/EEG/Source_Level_Analysis/Baseline_100sam_10ms_clear_all_erp.csv"
path="/home/sultan/EEG/Source_Level_Analysis/Baseline_100sam_10ms_clear_all_erp.csv"
dataset =pd.read_csv(path)

# %%
rs=40;
parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100],'gamma':[0.01,0.0147, 0.016, 0.019,0.029]}

# %%
Xc=dataset.iloc[:,2:].values
y=dataset.iloc[:,1].values
scaler = preprocessing.StandardScaler()
X = scaler.fit_transform(Xc)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.20, random_state=rs)

# %%
X_test.shape, y_test.shape
# Out:
# ((373, 1428), (373,))

# %%
np.unique(y_test)
np.unique(y_test,return_counts=True)
# Out:
# (array([0., 1.]), array([148, 225]))

# %% [markdown]
# # Whole brain

# %%
nstep=(X_train.shape[1]/68)
k=0;j=68; acgw=[];pmw=[];aucw=[];
for i in range(0,nstep):
    cv=5
#     from sklearn.model_selection import GridSearchCV
#     parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100,1000],'gamma':[0.01,0.0147, 0.016, 0.019, 0.021]}
    svc = svm.SVC()
    clf = GridSearchCV(svc, parameters,cv=cv)
    clf.fit(X_train[:,k:j], y_train)
    pred=clf.best_estimator_.predict(X_test[:,k:j])
    acc=clf.score(X_test[:,k:j], y_test)
    acgw=np.append(acgw,acc)
#     print (i*10);
    print "Accuracy:",acc
    perf=classification_report(y_test, pred)
    pmw.append(perf)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,pred)
    roc_auc=metrics.auc(fpr, tpr)
    roc_auc
    aucw.append(roc_auc)
    print"ROC", roc_auc
    print perf
    print k,j
    k=k+68;j=j+68;
#     scores=clf.cv_results_['mean_test_score']
#     print("Accuracy:%0.3f (+/-%0.3f)" %(scores.mean(), scores.std()*2))
# Out:
# Accuracy: 0.6032171581769437
# ROC 0.5
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00       148
#         1.0       0.60      1.00      0.75       225
#
# avg / total       0.36      0.60      0.45       373
#
# 0 68
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy: 0.67828418230563
# ROC 0.6604954954954956
#              precision    recall  f1-score   support
#
#         0.0       0.60      0.57      0.59       148
#         1.0       0.73      0.75      0.74       225
#
# avg / total       0.68      0.68      0.68       373
#
# 68 136
# Accuracy: 0.7024128686327078
# ROC 0.6747147147147147
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.54      0.59       148
#         1.0       0.73      0.81      0.77       225
#
# avg / total       0.70      0.70      0.70       373
#
# 136 204
# Accuracy: 0.7345844504021448
# ROC 0.7164114114114115
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.63      0.65       148
#         1.0       0.77      0.80      0.79       225
#
# avg / total       0.73      0.73      0.73       373
#
# 204 272
# Accuracy: 0.7989276139410187
# ROC 0.7928678678678678
#              precision    recall  f1-score   support
#
#         0.0       0.74      0.76      0.75       148
#         1.0       0.84      0.82      0.83       225
#
# avg / total       0.80      0.80      0.80       373
#
# 272 340
# Accuracy: 0.7828418230563002
# ROC 0.7806906906906907
#              precision    recall  f1-score   support
#
#         0.0       0.71      0.77      0.74       148
#         1.0       0.84      0.79      0.81       225
#
# avg / total       0.79      0.78      0.78       373
#
# 340 408
# Accuracy: 0.8150134048257373
# ROC 0.8073573573573575
#              precision    recall  f1-score   support
#
#         0.0       0.77      0.77      0.77       148
#         1.0       0.85      0.84      0.85       225
#
# avg / total       0.82      0.82      0.82       373
#
# 408 476
# Accuracy: 0.7560321715817694
# ROC 0.7515315315315316
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.73      0.70       148
#         1.0       0.81      0.77      0.79       225
#
# avg / total       0.76      0.76      0.76       373
#
# 476 544
# Accuracy: 0.7908847184986595
# ROC 0.7746396396396397
#              precision    recall  f1-score   support
#
#         0.0       0.76      0.70      0.73       148
#         1.0       0.81      0.85      0.83       225
#
# avg / total       0.79      0.79      0.79       373
#
# 544 612
# Accuracy: 0.7131367292225201
# ROC 0.700945945945946
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.64      0.64       148
#         1.0       0.76      0.76      0.76       225
#
# avg / total       0.71      0.71      0.71       373
#
# 612 680
# Accuracy: 0.7238605898123325
# ROC 0.7086786786786786
#              precision    recall  f1-score   support
#
#         0.0       0.66      0.64      0.65       148
#         1.0       0.77      0.78      0.77       225
#
# avg / total       0.72      0.72      0.72       373
#
# 680 748
# Accuracy: 0.7801608579088471
# ROC 0.7692192192192192
#              precision    recall  f1-score   support
#
#         0.0       0.73      0.72      0.72       148
#         1.0       0.81      0.82      0.82       225
#
# avg / total       0.78      0.78      0.78       373
#
# 748 816
# Accuracy: 0.7613941018766756
# ROC 0.7536636636636637
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.72      0.70       148
#         1.0       0.81      0.79      0.80       225
#
# avg / total       0.76      0.76      0.76       373
#
# 816 884
# Accuracy: 0.7345844504021448
# ROC 0.7349099099099099
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.74      0.69       148
#         1.0       0.81      0.73      0.77       225
#
# avg / total       0.74      0.73      0.74       373
#
# 884 952
# Accuracy: 0.7292225201072386
# ROC 0.7212162162162161
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.68      0.67       148
#         1.0       0.78      0.76      0.77       225
#
# avg / total       0.73      0.73      0.73       373
#
# 952 1020
# Accuracy: 0.7774798927613941
# ROC 0.7704654654654655
#              precision    recall  f1-score   support
#
#         0.0       0.71      0.74      0.72       148
#         1.0       0.82      0.80      0.81       225
#
# avg / total       0.78      0.78      0.78       373
#
# 1020 1088
# Accuracy: 0.7721179624664879
# ROC 0.7729579579579579
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.78      0.73       148
#         1.0       0.84      0.77      0.80       225
#
# avg / total       0.78      0.77      0.77       373
#
# 1088 1156
# Accuracy: 0.7453083109919572
# ROC 0.7403303303303304
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.72      0.69       148
#         1.0       0.80      0.76      0.78       225
#
# avg / total       0.75      0.75      0.75       373
#
# 1156 1224
# Accuracy: 0.7345844504021448
# ROC 0.7106306306306305
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.59      0.64       148
#         1.0       0.76      0.83      0.79       225
#
# avg / total       0.73      0.73      0.73       373
#
# 1224 1292
# Accuracy: 0.6943699731903485
# ROC 0.6877027027027027
#              precision    recall  f1-score   support
#
#         0.0       0.61      0.66      0.63       148
#         1.0       0.76      0.72      0.74       225
#
# avg / total       0.70      0.69      0.70       373
#
# 1292 1360
# Accuracy: 0.7158176943699732
# ROC 0.7181981981981982
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.73      0.67       148
#         1.0       0.80      0.71      0.75       225
#
# avg / total       0.73      0.72      0.72       373
#
# 1360 1428

# %% [markdown]
# # Hemisphrere analysis

# %% [markdown]
# ## LH

# %%
# only 34 features 
# parameters = {'kernel':['rbf'], 'C':[1, 10,20,30,70, 90,100,1000],'gamma':[0.015,0.025, 0.029, 0.030,2/5508.0,1/5508.0]}
a=range(0,(X.shape[1]),2)
d11=X[:,a];
X_train, X_test, y_train, y_test = train_test_split(d11,y, test_size=.20, random_state=rs) 
svc = svm.SVC()
k=0;j=34; acgr=[];aucrh=[];pmrh=[];
for i in range(0,nstep):
    cv=5
#     from sklearn.model_selection import GridSearchCV
#     parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100,1000],'gamma':[0.015,0.025, 0.029, 0.030,0.035]}
#     parameters = {'kernel':['rbf'], 'C':[1, 10,100,1000],'gamma':[0.01,2/1428.0,1/1428.0]}
    svc = svm.SVC()
    clf = GridSearchCV(svc, parameters,cv=cv)
    clf.fit(X_train[:,k:j], y_train)
    pred=clf.best_estimator_.predict(X_test[:,k:j])
    acc=clf.score(X_test[:,k:j], y_test)
    acgr=np.append(acgr,acc)
    print i*10
    print "Accuracy:", acc
    perf=classification_report(y_test, pred)
    pmrh.append(perf)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,pred)
    roc_auc=metrics.auc(fpr, tpr)
    roc_auc
    aucrh.append(roc_auc)
    print "ROC:", roc_auc
    print perf
#     print("Con:",confusion_matrix(y_test, pred))
    print k,j
    k=k+34;j=j+34;
# Out:
# 0
# Accuracy: 0.6032171581769437
# ROC: 0.5
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00       148
#         1.0       0.60      1.00      0.75       225
#
# avg / total       0.36      0.60      0.45       373
#
# 0 34
# 10
# Accuracy: 0.6729222520107239
# ROC: 0.6548948948948949
#              precision    recall  f1-score   support
#
#         0.0       0.59      0.57      0.58       148
#         1.0       0.72      0.74      0.73       225
#
# avg / total       0.67      0.67      0.67       373
#
# 34 68
# 20
# Accuracy: 0.7131367292225201
# ROC: 0.7148198198198199
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.72      0.67       148
#         1.0       0.80      0.71      0.75       225
#
# avg / total       0.72      0.71      0.72       373
#
# 68 102
# 30
# Accuracy: 0.6997319034852547
# ROC: 0.6990840840840842
#              precision    recall  f1-score   support
#
#         0.0       0.61      0.70      0.65       148
#         1.0       0.78      0.70      0.74       225
#
# avg / total       0.71      0.70      0.70       373
#
# 102 136
# 40
# Accuracy: 0.739946380697051
# ROC: 0.7393543543543544
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.74      0.69       148
#         1.0       0.81      0.74      0.77       225
#
# avg / total       0.75      0.74      0.74       373
#
# 136 170
# 50
# Accuracy: 0.7587131367292225
# ROC: 0.7525975975975977
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.72      0.70       148
#         1.0       0.81      0.78      0.80       225
#
# avg / total       0.76      0.76      0.76       373
#
# 170 204
# 60
# Accuracy: 0.7372654155495979
# ROC: 0.7301951951951953
#              precision    recall  f1-score   support
#
#         0.0       0.66      0.70      0.68       148
#         1.0       0.79      0.76      0.78       225
#
# avg / total       0.74      0.74      0.74       373
#
# 204 238
# 70
# Accuracy: 0.7345844504021448
# ROC: 0.7337537537537537
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.73      0.69       148
#         1.0       0.81      0.74      0.77       225
#
# avg / total       0.74      0.73      0.74       373
#
# 238 272
# 80
# Accuracy: 0.7024128686327078
# ROC: 0.6932132132132132
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.65      0.63       148
#         1.0       0.76      0.74      0.75       225
#
# avg / total       0.71      0.70      0.70       373
#
# 272 306
# 90
# Accuracy: 0.6916890080428955
# ROC: 0.6901051051051051
#              precision    recall  f1-score   support
#
#         0.0       0.60      0.68      0.64       148
#         1.0       0.77      0.70      0.73       225
#
# avg / total       0.70      0.69      0.69       373
#
# 306 340
# 100
# Accuracy: 0.707774798927614
# ROC: 0.69996996996997
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.66      0.64       148
#         1.0       0.77      0.74      0.75       225
#
# avg / total       0.71      0.71      0.71       373
#
# 340 374
# 110
# Accuracy: 0.7319034852546917
# ROC: 0.7245945945945946
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.69      0.67       148
#         1.0       0.79      0.76      0.77       225
#
# avg / total       0.73      0.73      0.73       373
#
# 374 408
# 120
# Accuracy: 0.7479892761394102
# ROC: 0.7425525525525525
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.72      0.69       148
#         1.0       0.80      0.77      0.79       225
#
# avg / total       0.75      0.75      0.75       373
#
# 408 442
# 130
# Accuracy: 0.6863270777479893
# ROC: 0.6821921921921923
#              precision    recall  f1-score   support
#
#         0.0       0.59      0.66      0.63       148
#         1.0       0.76      0.70      0.73       225
#
# avg / total       0.69      0.69      0.69       373
#
# 442 476
# 140
# Accuracy: 0.7453083109919572
# ROC: 0.7449549549549549
#              precision    recall  f1-score   support
#
#         0.0       0.66      0.74      0.70       148
#         1.0       0.82      0.75      0.78       225
#
# avg / total       0.75      0.75      0.75       373
#
# 476 510
# 150
# Accuracy: 0.7265415549597856
# ROC: 0.7282432432432433
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.74      0.68       148
#         1.0       0.81      0.72      0.76       225
#
# avg / total       0.74      0.73      0.73       373
#
# 510 544
# 160
# Accuracy: 0.7158176943699732
# ROC: 0.7251351351351352
#              precision    recall  f1-score   support
#
#         0.0       0.61      0.77      0.68       148
#         1.0       0.82      0.68      0.74       225
#
# avg / total       0.74      0.72      0.72       373
#
# 544 578
# 170
# Accuracy: 0.707774798927614
# ROC: 0.7045945945945946
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.69      0.65       148
#         1.0       0.78      0.72      0.75       225
#
# avg / total       0.72      0.71      0.71       373
#
# 578 612
# 180
# Accuracy: 0.6970509383378016
# ROC: 0.6853003003003004
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.63      0.62       148
#         1.0       0.75      0.74      0.75       225
#
# avg / total       0.70      0.70      0.70       373
#
# 612 646
# 190
# Accuracy: 0.6675603217158177
# ROC: 0.6643243243243244
#              precision    recall  f1-score   support
#
#         0.0       0.57      0.65      0.61       148
#         1.0       0.75      0.68      0.71       225
#
# avg / total       0.68      0.67      0.67       373
#
# 646 680
# 200
# Accuracy: 0.6702412868632708
# ROC: 0.6700150150150149
#              precision    recall  f1-score   support
#
#         0.0       0.57      0.67      0.62       148
#         1.0       0.76      0.67      0.71       225
#
# avg / total       0.68      0.67      0.67       373
#
# 680 714

# %% [markdown]
# # RH

# %%
b=range(1,(X.shape[1]),2)
d22=X[:,b];
X_train, X_test, y_train, y_test = train_test_split(d22,y, test_size=.20, random_state=rs) 
k=0;j=34; acgl=[];auclh=[];pmlh=[];
for i in range(0,nstep):
    cv=5
#     from sklearn.model_selection import GridSearchCV
#     parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100,1000],'gamma':[0.015,0.025, 0.029, 0.030,0.035]} 
#     parameters = {'kernel':['rbf'], 'C':[1, 10,100,1000],'gamma':[0.01,2/1428.0,1/1428.0]}
#     parameters = {'kernel':['rbf'], 'C':[1, 10,20,30, 40, 50, 60, 70, 90,100,1000],'gamma':[0.015,0.025, 0.029, 0.030,0.035]}
    svc = svm.SVC()
    clf = GridSearchCV(svc, parameters,cv=cv)
    clf.fit(X_train[:,k:j], y_train)
    pred=clf.best_estimator_.predict(X_test[:,k:j])
    acc=clf.score(X_test[:,k:j], y_test)
    acgl=np.append(acgl,acc)
    print i*10
    print "Accuracy:", acc
    perf=classification_report(y_test, pred)
    pmlh.append(perf)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,pred)
    roc_auc=metrics.auc(fpr, tpr)
    roc_auc
    auclh.append(roc_auc)
    print "ROC:", roc_auc
    print perf
#     print("Con:",confusion_matrix(y_test, pred))
    print k,j
    k=k+34;j=j+34;
# Out:
# 0
# Accuracy: 0.6032171581769437
# ROC: 0.5
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00       148
#         1.0       0.60      1.00      0.75       225
#
# avg / total       0.36      0.60      0.45       373
#
# 0 34
# 10
# Accuracy: 0.6621983914209115
# ROC: 0.6552552552552553
#              precision    recall  f1-score   support
#
#         0.0       0.57      0.62      0.59       148
#         1.0       0.73      0.69      0.71       225
#
# avg / total       0.67      0.66      0.66       373
#
# 34 68
# 20
# Accuracy: 0.6890080428954424
# ROC: 0.6647597597597599
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.55      0.58       148
#         1.0       0.72      0.78      0.75       225
#
# avg / total       0.68      0.69      0.68       373
#
# 68 102
# 30
# Accuracy: 0.7265415549597856
# ROC: 0.7247747747747748
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.72      0.68       148
#         1.0       0.80      0.73      0.76       225
#
# avg / total       0.73      0.73      0.73       373
#
# 102 136
# 40
# Accuracy: 0.7587131367292225
# ROC: 0.7606906906906907
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.77      0.72       148
#         1.0       0.83      0.75      0.79       225
#
# avg / total       0.77      0.76      0.76       373
#
# 136 170
# 50
# Accuracy: 0.7774798927613941
# ROC: 0.7704654654654655
#              precision    recall  f1-score   support
#
#         0.0       0.71      0.74      0.72       148
#         1.0       0.82      0.80      0.81       225
#
# avg / total       0.78      0.78      0.78       373
#
# 170 204
# 60
# Accuracy: 0.7962466487935657
# ROC: 0.7975825825825826
#              precision    recall  f1-score   support
#
#         0.0       0.72      0.80      0.76       148
#         1.0       0.86      0.79      0.82       225
#
# avg / total       0.80      0.80      0.80       373
#
# 204 238
# 70
# Accuracy: 0.7613941018766756
# ROC: 0.7606006006006008
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.76      0.72       148
#         1.0       0.83      0.76      0.79       225
#
# avg / total       0.77      0.76      0.76       373
#
# 238 272
# 80
# Accuracy: 0.7506702412868632
# ROC: 0.7436186186186184
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.71      0.69       148
#         1.0       0.80      0.78      0.79       225
#
# avg / total       0.75      0.75      0.75       373
#
# 272 306
# 90
# Accuracy: 0.67828418230563
# ROC: 0.6697447447447449
#              precision    recall  f1-score   support
#
#         0.0       0.59      0.63      0.61       148
#         1.0       0.74      0.71      0.73       225
#
# avg / total       0.68      0.68      0.68       373
#
# 306 340
# 100
# Accuracy: 0.7533512064343163
# ROC: 0.7504654654654654
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.74      0.70       148
#         1.0       0.82      0.76      0.79       225
#
# avg / total       0.76      0.75      0.75       373
#
# 340 374
# 110
# Accuracy: 0.7506702412868632
# ROC: 0.7378378378378379
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.68      0.68       148
#         1.0       0.79      0.80      0.79       225
#
# avg / total       0.75      0.75      0.75       373
#
# 374 408
# 120
# Accuracy: 0.7613941018766756
# ROC: 0.7582882882882883
#              precision    recall  f1-score   support
#
#         0.0       0.68      0.74      0.71       148
#         1.0       0.82      0.77      0.80       225
#
# avg / total       0.77      0.76      0.76       373
#
# 408 442
# 130
# Accuracy: 0.7292225201072386
# ROC: 0.7258408408408409
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.71      0.68       148
#         1.0       0.80      0.74      0.77       225
#
# avg / total       0.74      0.73      0.73       373
#
# 442 476
# 140
# Accuracy: 0.7184986595174263
# ROC: 0.7192642642642643
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.72      0.67       148
#         1.0       0.80      0.72      0.75       225
#
# avg / total       0.73      0.72      0.72       373
#
# 476 510
# 150
# Accuracy: 0.7158176943699732
# ROC: 0.7031681681681682
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.64      0.64       148
#         1.0       0.76      0.76      0.76       225
#
# avg / total       0.72      0.72      0.72       373
#
# 510 544
# 160
# Accuracy: 0.7292225201072386
# ROC: 0.7304654654654654
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.74      0.68       148
#         1.0       0.81      0.72      0.76       225
#
# avg / total       0.74      0.73      0.73       373
#
# 544 578
# 170
# Accuracy: 0.6890080428954424
# ROC: 0.6809459459459459
#              precision    recall  f1-score   support
#
#         0.0       0.60      0.64      0.62       148
#         1.0       0.75      0.72      0.74       225
#
# avg / total       0.69      0.69      0.69       373
#
# 578 612
# 180
# Accuracy: 0.710455764075067
# ROC: 0.7033483483483483
#              precision    recall  f1-score   support
#
#         0.0       0.63      0.67      0.65       148
#         1.0       0.77      0.74      0.75       225
#
# avg / total       0.71      0.71      0.71       373
#
# 612 646
# 190
# Accuracy: 0.710455764075067
# ROC: 0.7149099099099099
#              precision    recall  f1-score   support
#
#         0.0       0.61      0.74      0.67       148
#         1.0       0.80      0.69      0.74       225
#
# avg / total       0.73      0.71      0.71       373
#
# 646 680
# 200
# Accuracy: 0.6890080428954424
# ROC: 0.6925075075075074
#              precision    recall  f1-score   support
#
#         0.0       0.59      0.71      0.64       148
#         1.0       0.78      0.68      0.72       225
#
# avg / total       0.70      0.69      0.69       373
#
# 680 714

# %%
t=np.linspace(0,200,21, endpoint=True)
time=pd.DataFrame(t)
# a=pd.concat([time,pd.DataFrame(acgw),pd.DataFrame(acgl),pd.DataFrame(acgr)],axis=1, keys=[ 'time',"Whole", "LH", "RH"])
a=pd.concat([time,pd.DataFrame(acgw),pd.DataFrame(acgr),pd.DataFrame(acgl)],axis=1, keys=[ 'time',"Whole", "LH", "RH"])

# %%
np.max(acgl)
np.max(a.iloc[:,3])
# Out:
# 0.7962466487935657

# %%
a
# Out:
#      time     Whole        LH        RH
#         0         0         0         0
# 0     0.0  0.603217  0.603217  0.603217
# 1    10.0  0.678284  0.672922  0.662198
# 2    20.0  0.702413  0.713137  0.689008
# 3    30.0  0.734584  0.699732  0.726542
# 4    40.0  0.798928  0.739946  0.758713
# 5    50.0  0.782842  0.758713  0.777480
# 6    60.0  0.815013  0.737265  0.796247
# 7    70.0  0.756032  0.734584  0.761394
# 8    80.0  0.790885  0.702413  0.750670
# 9    90.0  0.713137  0.691689  0.678284
# 10  100.0  0.723861  0.707775  0.753351
# 11  110.0  0.780161  0.731903  0.750670
# 12  120.0  0.761394  0.747989  0.761394
# 13  130.0  0.734584  0.686327  0.729223
# 14  140.0  0.729223  0.745308  0.718499
# 15  150.0  0.777480  0.726542  0.715818
# 16  160.0  0.772118  0.715818  0.729223
# 17  170.0  0.745308  0.707775  0.689008
# 18  180.0  0.734584  0.697051  0.710456
# 19  190.0  0.694370  0.667560  0.710456
# 20  200.0  0.715818  0.670241  0.689008

# %% [markdown]
# # Writing the csv data all

# %%
# wpath="/home/sultan/EEG/Source_Level_Analysis/SVM_results/"
# dall=a
# dall.to_csv(wpath+'svm_baseline_100sam_10ms_clear_v2.csv')

# %%
axis_font = {'fontname':'Arial', 'size':'15'}
#tw1=tad.iloc[1:,0];Acdw1=tad.iloc[1:,1];
tw1=a.iloc[0:,0];Acdw=a.iloc[0:,1];Acdlh=a.iloc[0:,2];Acdrh=a.iloc[0:,3]
# plt.plot(tw1,Acdw1,c='g')
plt.plot(tw1,Acdw,'g',linewidth=2,marker='*')
plt.plot(tw1, Acdlh,'--r',linewidth=2,marker='o')
plt.plot(tw1, Acdrh,'--b',linewidth=2,marker='x')
plt.title("100ms_10ms_clear")
plt.xlim(0,200)
# plt.plot(tw1,Acdw1, 'k--', label='noise')
# plt.xlabel('Time (ms)',**axis_font)
# plt.ylabel('Accuracy (%)',**axis_font)
# plt.title('Whole brain',**axis_font)
# plt.yticks(**axis_font)
# plt.xticks(**axis_font)
plt.grid(True)
plt.tight_layout()
plt.gca().legend(('Whole','LH','RH'),fontsize=16,loc='best')
# plt.savefig('whole_acc_timem.eps')
# plt.savefig('whole_acc_timem.tif')
plt.show()

# %% [markdown]
# # STOPPPPPPPPPPPPPP

# %% [markdown]
# 1. This is the text for
#    gfhfhufy
